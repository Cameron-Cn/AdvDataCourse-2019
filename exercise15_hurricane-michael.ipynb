# %% [markdown]
# # Exercise No. 15
# ## Hurricane Michael Path
# #### 2019 June 25 | Cameron.Cn

# %%
# Import libraries--always a first!
import pandas as pd
import geopandas as gpd #used for transforming geolocation data
import numpy as np
import matplotlib.pyplot as plt

from datetime import datetime  #to convert data to datetime that does not fall within the pandas.to_datetime function timeframe
from shapely.geometry import Point  #transform latitude/longitude to geo-coordinate data
from geopandas.tools import geocode #get the latitude/longitude for a given address
from geopandas.tools import reverse_geocode  #get the address for a location using latitude/longitude

# %matplotlib inline

# %%
# bringing in the dataset for hurricane Michael
hurr = pd.read_csv("../AdvData_DATASETS/datasets_hurricaneMichael.csv")
hurr.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  10/06/2018 17:00  18.0  86.6    30  1006
# 1             1A  10/06/2018 20:00  18.3  86.6    30  1004
# 2              2  10/06/2018 23:00  18.8  86.6    30  1004
# 3             2A  10/07/2018 02:00  18.4  87.1    35  1004
# 4              3  10/07/2018 05:00  18.6  86.9    35  1004
#
#                  Movement                        Type      Name  \
# 0   NW at 6 MPH (325 deg)  Potential Tropical Cyclone  Fourteen
# 1    N at 6 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 2    N at 7 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 3   NW at 5 MPH (320 deg)  Potential Tropical Cyclone  Fourteen
# 4  NNW at 3 MPH (340 deg)         Tropical Depression  FOURTEEN
#
#            Received Forecaster
# 0  10/06/2018 16:50      Beven
# 1  10/06/2018 19:32      Avila
# 2  10/06/2018 22:38      Avila
# 3  10/07/2018 01:38       Berg
# 4  10/07/2018 04:53       Berg

# %%
# making sure there is consistent data in each field
hurr.count()
# Out:
# AdvisoryNumber    45
# Date              45
# Lat               45
# Long              45
# Wind              45
# Pres              45
# Movement          45
# Type              45
# Name              45
# Received          45
# Forecaster        45
# dtype: int64

# %%
# making the the longitude negative as it has to be for N.America
hurr['Long'] = 0 - hurr['Long']
hurr.head(2)
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  10/06/2018 17:00  18.0 -86.6    30  1006
# 1             1A  10/06/2018 20:00  18.3 -86.6    30  1004
#
#                 Movement                        Type      Name  \
# 0  NW at 6 MPH (325 deg)  Potential Tropical Cyclone  Fourteen
# 1   N at 6 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
#
#            Received Forecaster   coordinates
# 0  10/06/2018 16:50      Beven  [86.6, 18.0]
# 1  10/06/2018 19:32      Avila  [86.6, 18.3]

# %%
# setting up a new single column of location data
hurr['coordinates'] = list(hurr[['Long', 'Lat']].values)
hurr.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  10/06/2018 17:00  18.0 -86.6    30  1006
# 1             1A  10/06/2018 20:00  18.3 -86.6    30  1004
# 2              2  10/06/2018 23:00  18.8 -86.6    30  1004
# 3             2A  10/07/2018 02:00  18.4 -87.1    35  1004
# 4              3  10/07/2018 05:00  18.6 -86.9    35  1004
#
#                  Movement                        Type      Name  \
# 0   NW at 6 MPH (325 deg)  Potential Tropical Cyclone  Fourteen
# 1    N at 6 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 2    N at 7 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 3   NW at 5 MPH (320 deg)  Potential Tropical Cyclone  Fourteen
# 4  NNW at 3 MPH (340 deg)         Tropical Depression  FOURTEEN
#
#            Received Forecaster    coordinates
# 0  10/06/2018 16:50      Beven  [-86.6, 18.0]
# 1  10/06/2018 19:32      Avila  [-86.6, 18.3]
# 2  10/06/2018 22:38      Avila  [-86.6, 18.8]
# ...

# %%
# this is saying that our coordinates type is a 'O'
hurr['coordinates'].dtype
# Out:
# dtype('O')

# %%
# changing the format type to a point, checking the result
hurr['coordinates'] = hurr['coordinates'].apply(Point)
hurr.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  10/06/2018 17:00  18.0 -86.6    30  1006
# 1             1A  10/06/2018 20:00  18.3 -86.6    30  1004
# 2              2  10/06/2018 23:00  18.8 -86.6    30  1004
# 3             2A  10/07/2018 02:00  18.4 -87.1    35  1004
# 4              3  10/07/2018 05:00  18.6 -86.9    35  1004
#
#                  Movement                        Type      Name  \
# 0   NW at 6 MPH (325 deg)  Potential Tropical Cyclone  Fourteen
# 1    N at 6 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 2    N at 7 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 3   NW at 5 MPH (320 deg)  Potential Tropical Cyclone  Fourteen
# 4  NNW at 3 MPH (340 deg)         Tropical Depression  FOURTEEN
#
#            Received Forecaster                      coordinates
# 0  10/06/2018 16:50      Beven    POINT (-86.59999999999999 18)
# 1  10/06/2018 19:32      Avila  POINT (-86.59999999999999 18.3)
# ...

# %%
# now we create a data frame with the coordinates in the matrix
geo_hurri = gpd.GeoDataFrame(hurr, geometry='coordinates')

# %%
geo_hurri.head()
# Out:
#   AdvisoryNumber              Date   Lat  Long  Wind  Pres  \
# 0              1  10/06/2018 17:00  18.0 -86.6    30  1006
# 1             1A  10/06/2018 20:00  18.3 -86.6    30  1004
# 2              2  10/06/2018 23:00  18.8 -86.6    30  1004
# 3             2A  10/07/2018 02:00  18.4 -87.1    35  1004
# 4              3  10/07/2018 05:00  18.6 -86.9    35  1004
#
#                  Movement                        Type      Name  \
# 0   NW at 6 MPH (325 deg)  Potential Tropical Cyclone  Fourteen
# 1    N at 6 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 2    N at 7 MPH (360 deg)  Potential Tropical Cyclone  Fourteen
# 3   NW at 5 MPH (320 deg)  Potential Tropical Cyclone  Fourteen
# 4  NNW at 3 MPH (340 deg)         Tropical Depression  FOURTEEN
#
#            Received Forecaster                      coordinates
# 0  10/06/2018 16:50      Beven    POINT (-86.59999999999999 18)
# 1  10/06/2018 19:32      Avila  POINT (-86.59999999999999 18.3)
# ...

# %%
# getting our map of the us
filepath = "../AdvData_DATASETS/datasets_US_states(5m).json"

#data contains polygon shape coordinates for different map body types (continents, etc.)
map_df = gpd.read_file(filepath)
map_df.head()
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 1  0400000US02    02      Alaska       570640.950
# 2  0400000US04    04     Arizona       113594.084
# 3  0400000US05    05    Arkansas        52035.477
# 4  0400000US06    06  California       155779.220
#
#                                             geometry
# 0  (POLYGON ((-88.124658 30.28364, -88.0868119999...
# 1  (POLYGON ((-166.10574 53.988606, -166.075283 5...
# 2  POLYGON ((-112.538593 37.000674, -112.534545 3...
# 3  POLYGON ((-94.042964 33.019219, -94.043036 33....
# 4  (POLYGON ((-122.421439 37.869969, -122.421341 ...

# %%
# getting rid of Alaska and Hawai'i
map48 = map_df.loc[map_df['NAME'].isin(['Alaska', 'Hawaii', 'Puerto Rico']) == False]
map48.head()
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 2  0400000US04    04     Arizona       113594.084
# 3  0400000US05    05    Arkansas        52035.477
# 4  0400000US06    06  California       155779.220
# 5  0400000US08    08    Colorado       103641.888
#
#                                             geometry
# 0  (POLYGON ((-88.124658 30.28364, -88.0868119999...
# 2  POLYGON ((-112.538593 37.000674, -112.534545 3...
# 3  POLYGON ((-94.042964 33.019219, -94.043036 33....
# 4  (POLYGON ((-122.421439 37.869969, -122.421341 ...
# 5  POLYGON ((-106.190554 40.997607, -106.061181 4...

# %%
# look at our map!
map48.plot()

# %%
#geo_hurri.plot()
N = hurr['Wind']
x = geo_hurri['Long']
y = geo_hurri['Lat']
area = np.pi * (1 * (N))
plt.scatter(x,y, data=geo_hurri, s=area, alpha=0.5)

# %%
fig, ax = plt.subplots(1, figsize=(15,15)) # setting the base size of our plot chart (bigger!)
basemap = map48.plot(ax=ax, color='grey') # saying that the map at base will be equal to the larger plot size
geo_hurri.plot(column='Wind', ax=basemap, marker='.', markersize=80) # placing our hurricane geo on top

ax.axis('off')
ax.set_title("Hurricane!", fontsize=24)
# Out:
# Text(0.5, 1.0, 'Hurricane!')

# %%
# Plotting with variable marker size depending on wind speed:

fig, ax = plt.subplots(1, figsize=(12,14)) # setting the base size of our plot chart (bigger!)
basemap = map48.plot(ax=ax, color='grey') # saying that the map at base will be equal to the larger plot size

ax.axis('off')
ax.set_title("Hurricane!", fontsize=24, fontweight=3)

W = hurr['Wind'] # this will be the size of the dot
P = hurr['Pres'] # this will be the color of the dot
x = geo_hurri['Long'] # our x-axis
y = geo_hurri['Lat'] # our y-axis
area = np.pi * (0.8 * (W)) # the forumla to define the dot area (size)

plt.scatter(x,y, data=geo_hurri, s=area, alpha=0.8, c=P)
# this complex looking line sets all the above into the plot:
    # so the size of the dot is related to the wind speed
    # while the color is related to the pressure

#plt.savefig("hurricane.png")
